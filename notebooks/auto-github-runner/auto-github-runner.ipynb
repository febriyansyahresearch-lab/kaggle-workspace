# %%
# ===============================
# GITHUB → KAGGLE → AUTO RUN
# ===============================

import os
from datetime import datetime

# -------------------------------
# 1. Setup Variables
# -------------------------------
GITHUB_USER = "febriyansyahresearch-lab"
GITHUB_REPO = "kaggle-project"
GITHUB_TOKEN = \"YOUR_GITHUB_TOKEN_HERE\"  # Ganti dengan token GitHub kamu yang baru

WORK_DIR = "/kaggle/working"

# File / script yang ingin dijalankan
SCRIPT_TO_RUN = "src/train.py"           # ganti sesuai repo
NOTEBOOK_TO_RUN = None                    # misal "notebooks/train.ipynb"

# -------------------------------
# 2. Masuk Folder Kerja
# -------------------------------
os.chdir(WORK_DIR)
print("Working directory:", os.getcwd())

# Hapus folder lama untuk simulasi bersih (opsional)
# !rm -rf {GITHUB_REPO}

# -------------------------------
# 3. Clone Repository Private
# -------------------------------
# !git clone https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git

# Masuk folder repo
os.chdir(os.path.join(WORK_DIR, GITHUB_REPO))
print("Repository directory:", os.getcwd())
# !ls -la

# -------------------------------
# 4. Konfigurasi Git
# -------------------------------
# !git config --global user.name "Febriyansyah"
# !git config --global user.email "email@example.com"
# !git config --list | grep user

# -------------------------------
# 5. Commit File Baru / Log
# -------------------------------
# Contoh membuat file log otomatis
with open("training_log.txt","a") as f:
    f.write(f"Update: {datetime.now()}\n")

# Tambahkan semua perubahan
# !git add .

# Commit otomatis
commit_msg = f"Auto update from Kaggle - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"
# !git commit -m "{commit_msg}" || echo "Tidak ada perubahan untuk commit"

# -------------------------------
# 6. Push ke GitHub
# -------------------------------
# !git push https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git main

# -------------------------------
# 7. Jalankan Script atau Notebook
# -------------------------------
# Jalankan script Python
if SCRIPT_TO_RUN and os.path.exists(SCRIPT_TO_RUN):
    print(f"Menjalankan {SCRIPT_TO_RUN} ...")
    # !python {SCRIPT_TO_RUN}
else:
    print(f"{SCRIPT_TO_RUN} tidak ditemukan.")

# Jalankan notebook jika diisi
if NOTEBOOK_TO_RUN and os.path.exists(NOTEBOOK_TO_RUN):
    print(f"Menjalankan notebook {NOTEBOOK_TO_RUN} ...")
    # !jupyter nbconvert --to notebook --execute {NOTEBOOK_TO_RUN} --output executed_{NOTEBOOK_TO_RUN.replace('/', '_')}"
