# %% [markdown]
# # Kaggle Project - Starter Notebook
#
# Template notebook untuk eksplorasi data dan modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.preprocess import load_data, clean_data, encode_categorical, split_data, scale_features
from src.train import train_model, evaluate_model, save_model
from src.predict import predict_new, predict_proba_new

# %%
# Load data
# df = load_data('data/train.csv')
# df.head()

# %%
# EDA
# df.describe()
# df.info()

# %%
# Preprocessing
# df_clean = clean_data(df)
# df_encoded = encode_categorical(df_clean)
# X_train, X_test, y_train, y_test = split_data(df_encoded, target_col='target')
# X_train_scaled, X_test_scaled, scaler = scale_features(X_train, X_test)

# %%
# Training
# model = train_model(X_train_scaled, y_train)
# result = evaluate_model(model, X_test_scaled, y_test)
# print(f"Accuracy: {result['accuracy']:.4f}")

# %%
# Save model
# save_model(model)
# print("Model saved to models/model.joblib")
