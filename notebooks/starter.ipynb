# %% [markdown]
# # Kaggle Project — EDA & Modeling with Iris Dataset
#
# Contoh analisis menggunakan dataset Iris untuk demonstrasi pipeline.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

from src.preprocess import clean_data, encode_categorical, split_data, scale_features
from src.train import train_model, evaluate_model, save_model

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()

# %%
df.info()
df.describe()

# %%
sns.pairplot(df, hue='target')
plt.show()

# %%
X_train, X_test, y_train, y_test = split_data(df, target_col='target', test_size=0.2)
X_train_scaled, X_test_scaled, scaler = scale_features(X_train, X_test)

# %%
model = train_model(X_train_scaled, y_train, n_estimators=50, random_state=42)
result = evaluate_model(model, X_test_scaled, y_test)
print(f"Accuracy: {result['accuracy']:.4f}")

# %%
save_model(model)
print("Model saved to models/model.joblib")

# %% [markdown]
# ## Deploy API
#
# ```bash
# uvicorn src.api:app --reload
# ```
#
# Test: `curl -X POST http://localhost:8000/predict -H 'Content-Type: application/json' -d '{"data": [[5.1, 3.5, 1.4, 0.2]]}'`
# ```
